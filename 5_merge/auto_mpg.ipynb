# %% [markdown]
# # MPG CARS

# %%
# import necessary library

import pandas as pd
import numpy as np

# %%
# loading dataset

df_1 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars1.csv")
df_2 = pd.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/05_Merge/Auto_MPG/cars2.csv")

# %%
df_1.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %%
df_2.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0  33.0          4            91         53    1795          17.4     76
# 1  20.0          6           225        100    3651          17.7     76
# 2  18.0          6           250         78    3574          21.0     76
# 3  18.5          6           250        110    3645          16.2     76
# 4  17.5          6           258         95    3193          17.8     76
#
#    origin                 car
# 0       3         honda civic
# 1       1      dodge aspen se
# 2       1   ford granada ghia
# 3       1  pontiac ventura sj
# 4       1       amc pacer d/l

# %%
print(df_1.shape)
print(df_2.shape)
# Out:
# (198, 14)
# (200, 9)

# %%
# column name for df_1
df_1.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model', 'origin', 'car', 'Unnamed: 9', 'Unnamed: 10',
#        'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
# sorting the df_1 because it have some unnamed columln

df_1 = df_1.loc[:,"mpg":"car"]
df_1.columns.nunique()
# Out:
# 9

# %%
# join two data in new data set name as df

df = df_1.append(df_2)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_9976\3051174035.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df_1.append(df_2)

# %%
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  model  \
# 0    18.0          8           307        130    3504          12.0     70
# 1    15.0          8           350        165    3693          11.5     70
# 2    18.0          8           318        150    3436          11.0     70
# 3    16.0          8           304        150    3433          12.0     70
# 4    17.0          8           302        140    3449          10.5     70
# ..    ...        ...           ...        ...     ...           ...    ...
# 195  27.0          4           140         86    2790          15.6     82
# 196  44.0          4            97         52    2130          24.6     82
# 197  32.0          4           135         84    2295          11.6     82
# 198  28.0          4           120         79    2625          18.6     82
# 199  31.0          4           119         82    2720          19.4     82
#
#      origin                        car
# ...

# %%
# Create a random number Series from 15,000 to 73,000 and name it owners

owners = np.random.randint(15000, high = 73001, size= 398,dtype="l")
owners
# Out:
# array([24887, 22798, 25584, 20109, 24469, 23223, 20183, 55212, 56357,
#        55121, 65218, 71037, 22277, 50620, 42829, 24195, 31501, 64788,
#        28765, 39222, 28498, 16107, 69757, 30992, 53718, 68969, 43425,
#        42348, 37033, 34218, 48697, 43748, 62029, 47031, 51681, 16465,
#        62722, 15919, 51552, 18581, 44127, 65170, 69727, 30535, 70899,
#        33508, 58890, 23401, 33957, 36786, 21245, 18491, 36640, 62093,
#        64789, 67963, 40815, 55322, 69278, 38101, 20174, 39581, 67828,
#        22234, 34022, 41611, 22824, 44088, 52305, 22286, 18524, 17726,
#        15780, 45410, 67567, 46337, 47761, 21735, 59433, 27942, 62114,
#        48122, 29058, 18208, 15693, 49809, 43620, 32773, 54617, 68310,
#        17260, 58092, 50365, 47993, 42601, 35699, 55115, 35198, 22912,
#        54632, 49581, 65659, 34619, 58305, 70491, 26612, 72377, 47880,
#        41120, 42715, 39790, 33918, 41842, 66855, 55931, 62118, 38424,
# ...

# %%
# add this owners in df

df["owners"]= owners
df.columns.value_counts(.count()
# Out:
#   Input In [17]
#     df.columns.value_counts(.count()
#                             ^
# SyntaxError: invalid syntax
